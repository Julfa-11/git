# %% [markdown]
# <a href="https://colab.research.google.com/github/Julfa-11/git/blob/main/Tinted_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image, ImageEnhance
import matplotlib.pyplot as plt
im = Image.open("flower.jpg").convert("RGB")
blue_tint = Image.new("RGB",im.size,(255,0,255))
tinted = Image.blend(im,blue_tint,alpha=0.5)
plt.imshow(tinted)
plt.axis("off")
plt.title("Blue-Tined Image")
plt.show()
