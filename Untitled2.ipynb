# %% [markdown]
# <a href="https://colab.research.google.com/github/Julfa-11/git/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !jupyter nbextension disable --py widgetsnbextension
# Out:
# Disabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK
